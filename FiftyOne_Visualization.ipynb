# %%
import fiftyone as fo

# %%
name = "my-dataset-2"
dataset_dir = "/var/Data/Cotton Imaging Datasets/fiftyone_test"

# Create the dataset
dataset = fo.Dataset.from_dir(
    dataset_dir=dataset_dir,
    dataset_type=fo.types.COCODetectionDataset,
    label_types=["detections", "segmentations"],
    name=name,
)

# View summary info about the dataset
print(dataset)

# Print the first few samples in the dataset
print(dataset.head())
# Out:
#  100% |█████████████████████| 3/3 [188.5ms elapsed, 0s remaining, 15.9 samples/s]
# Name:        my-dataset-2
# Media type:  image
# Num samples: 3
# Persistent:  False
# Tags:        []
# Sample fields:
#     id:            fiftyone.core.fields.ObjectIdField
#     filepath:      fiftyone.core.fields.StringField
#     tags:          fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:      fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.Metadata)
#     detections:    fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
#     segmentations: fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
# [<Sample: {
#     'id': '6154b03d02522f81348fa107',
#     'media_type': 'image',
#     'filepath': '/var/Data/Cotton Imaging Datasets/Anotation_Test/frame1274.jpg',
#     'tags': BaseList([]),
#     'metadata': <ImageMetadata: {
#         'size_bytes': None,
#         'mime_type': None,
#         'width': 1280,
#         'height': 720,
#         'num_channels': None,
#     }>,
#     'detections': <Detections: {
#         'detections': BaseList([
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0db',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.5640625,
#                     0.6597222222222222,
#                     0.04921875,
#                     0.11944444444444445,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0dc',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.5953125,
#                     0.6069444444444444,
#                     0.05234375,
#                     0.09027777777777778,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0dd',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Open Boll',
#                 'bounding_box': BaseList([
#                     0.678125,
#                     0.7333333333333333,
#                     0.04453125,
#                     0.10416666666666667,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Open Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0de',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Open Boll',
#                 'bounding_box': BaseList([
#                     0.51953125,
#                     0.7097222222222223,
#                     0.0375,
#                     0.04861111111111111,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Open Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0df',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.603125,
#                     0.4986111111111111,
#                     0.03671875,
#                     0.059722222222222225,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0e0',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.4234375,
#                     0.6694444444444444,
#                     0.03359375,
#                     0.058333333333333334,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0e1',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.44453125,
#                     0.36944444444444446,
#                     0.025,
#                     0.04583333333333333,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0e2',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.41484375,
#                     0.3416666666666667,
#                     0.02890625,
#                     0.04861111111111111,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0e3',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.65546875,
#                     0.1486111111111111,
#                     0.03984375,
#                     0.09166666666666666,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0e4',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([0.721875, 0.225, 0.04375, 0.08194444444444444]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0e5',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.76015625,
#                     0.2513888888888889,
#                     0.0453125,
#                     0.0763888888888889,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0e6',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.89296875,
#                     0.30277777777777776,
#                     0.0484375,
#                     0.06111111111111111,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0e7',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.05078125,
#                     0.5472222222222223,
#                     0.065625,
#                     0.10277777777777777,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0e8',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.1734375,
#                     0.3763888888888889,
#                     0.0265625,
#                     0.0625,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0e9',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.10078125,
#                     0.8916666666666667,
#                     0.05703125,
#                     0.09305555555555556,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0ea',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([0.2828125, 0.4777777777777778, 0.0421875, 0.075]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0eb',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.2375,
#                     0.21805555555555556,
#                     0.04140625,
#                     0.08611111111111111,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0ec',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Square',
#                 'bounding_box': BaseList([
#                     0.48046875,
#                     0.10694444444444444,
#                     0.02890625,
#                     0.09583333333333334,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Square',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0ed',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.67421875,
#                     0.3486111111111111,
#                     0.03203125,
#                     0.06805555555555555,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0ee',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.69921875,
#                     0.41944444444444445,
#                     0.0328125,
#                     0.05694444444444444,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0ef',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.884375,
#                     0.09027777777777778,
#                     0.0515625,
#                     0.06111111111111111,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0f0',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.7328125,
#                     0.8097222222222222,
#                     0.0578125,
#                     0.06111111111111111,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#         ]),
#     }>,
#     'segmentations': <Detections: {
#         'detections': BaseList([
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0f1',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.5640625,
#                     0.6597222222222222,
#                     0.04921875,
#                     0.11944444444444445,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0f2',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.5953125,
#                     0.6069444444444444,
#                     0.05234375,
#                     0.09027777777777778,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0f3',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Open Boll',
#                 'bounding_box': BaseList([
#                     0.678125,
#                     0.7333333333333333,
#                     0.04453125,
#                     0.10416666666666667,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Open Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0f4',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Open Boll',
#                 'bounding_box': BaseList([
#                     0.51953125,
#                     0.7097222222222223,
#                     0.0375,
#                     0.04861111111111111,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Open Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0f5',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.603125,
#                     0.4986111111111111,
#                     0.03671875,
#                     0.059722222222222225,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0f6',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.4234375,
#                     0.6694444444444444,
#                     0.03359375,
#                     0.058333333333333334,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0f7',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.44453125,
#                     0.36944444444444446,
#                     0.025,
#                     0.04583333333333333,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0f8',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.41484375,
#                     0.3416666666666667,
#                     0.02890625,
#                     0.04861111111111111,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ...,  True,  True, False],
#                        [False, False, False, ...,  True, False, False],
#                        [False, False, False, ...,  True, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0f9',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.65546875,
#                     0.1486111111111111,
#                     0.03984375,
#                     0.09166666666666666,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0fa',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([0.721875, 0.225, 0.04375, 0.08194444444444444]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0fb',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.76015625,
#                     0.2513888888888889,
#                     0.0453125,
#                     0.0763888888888889,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0fc',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.89296875,
#                     0.30277777777777776,
#                     0.0484375,
#                     0.06111111111111111,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0fd',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.05078125,
#                     0.5472222222222223,
#                     0.065625,
#                     0.10277777777777777,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0fe',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.1734375,
#                     0.3763888888888889,
#                     0.0265625,
#                     0.0625,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa0ff',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.10078125,
#                     0.8916666666666667,
#                     0.05703125,
#                     0.09305555555555556,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa100',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([0.2828125, 0.4777777777777778, 0.0421875, 0.075]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa101',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.2375,
#                     0.21805555555555556,
#                     0.04140625,
#                     0.08611111111111111,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa102',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Square',
#                 'bounding_box': BaseList([
#                     0.48046875,
#                     0.10694444444444444,
#                     0.02890625,
#                     0.09583333333333334,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Square',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa103',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.67421875,
#                     0.3486111111111111,
#                     0.03203125,
#                     0.06805555555555555,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa104',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.69921875,
#                     0.41944444444444445,
#                     0.0328125,
#                     0.05694444444444444,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa105',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.884375,
#                     0.09027777777777778,
#                     0.0515625,
#                     0.06111111111111111,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ...,  True,  True, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa106',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.7328125,
#                     0.8097222222222222,
#                     0.0578125,
#                     0.06111111111111111,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#         ]),
#     }>,
# }>, <Sample: {
#     'id': '6154b03d02522f81348fa148',
#     'media_type': 'image',
#     'filepath': '/var/Data/Cotton Imaging Datasets/Anotation_Test/frame2700.jpg',
#     'tags': BaseList([]),
#     'metadata': <ImageMetadata: {
#         'size_bytes': None,
#         'mime_type': None,
#         'width': 1280,
#         'height': 720,
#         'num_channels': None,
#     }>,
#     'detections': <Detections: {
#         'detections': BaseList([
#             <Detection: {
#                 'id': '6154b03d02522f81348fa134',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.36171875,
#                     0.2916666666666667,
#                     0.05703125,
#                     0.09861111111111111,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa135',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.1953125,
#                     0.2125,
#                     0.0546875,
#                     0.10277777777777777,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa136',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.1375,
#                     0.6527777777777778,
#                     0.0734375,
#                     0.10555555555555556,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa137',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.66015625,
#                     0.49166666666666664,
#                     0.0375,
#                     0.07083333333333333,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa138',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.85078125,
#                     0.45694444444444443,
#                     0.05390625,
#                     0.08333333333333333,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa139',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.45,
#                     0.23055555555555557,
#                     0.03671875,
#                     0.06388888888888888,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa13a',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.1453125,
#                     0.2375,
#                     0.03828125,
#                     0.03888888888888889,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa13b',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.02734375,
#                     0.19722222222222222,
#                     0.04453125,
#                     0.08888888888888889,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#         ]),
#     }>,
#     'segmentations': <Detections: {
#         'detections': BaseList([
#             <Detection: {
#                 'id': '6154b03d02522f81348fa13c',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.36171875,
#                     0.2916666666666667,
#                     0.05703125,
#                     0.09861111111111111,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa13d',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.1953125,
#                     0.2125,
#                     0.0546875,
#                     0.10277777777777777,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [ True,  True,  True, ..., False, False, False],
#                        [False,  True,  True, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa13e',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.1375,
#                     0.6527777777777778,
#                     0.0734375,
#                     0.10555555555555556,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa13f',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.66015625,
#                     0.49166666666666664,
#                     0.0375,
#                     0.07083333333333333,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa140',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.85078125,
#                     0.45694444444444443,
#                     0.05390625,
#                     0.08333333333333333,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa141',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.45,
#                     0.23055555555555557,
#                     0.03671875,
#                     0.06388888888888888,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa142',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.1453125,
#                     0.2375,
#                     0.03828125,
#                     0.03888888888888889,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa143',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Closed Boll',
#                 'bounding_box': BaseList([
#                     0.02734375,
#                     0.19722222222222222,
#                     0.04453125,
#                     0.08888888888888889,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Closed Boll',
#                 'iscrowd': 0,
#             }>,
#         ]),
#     }>,
# }>, <Sample: {
#     'id': '6154b03d02522f81348fa149',
#     'media_type': 'image',
#     'filepath': '/var/Data/Cotton Imaging Datasets/Anotation_Test/frame2972.jpg',
#     'tags': BaseList([]),
#     'metadata': <ImageMetadata: {
#         'size_bytes': None,
#         'mime_type': None,
#         'width': 1280,
#         'height': 720,
#         'num_channels': None,
#     }>,
#     'detections': <Detections: {
#         'detections': BaseList([
#             <Detection: {
#                 'id': '6154b03d02522f81348fa144',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Square',
#                 'bounding_box': BaseList([0.459375, 0.625, 0.053125, 0.15555555555555556]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Square',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa145',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Flower',
#                 'bounding_box': BaseList([
#                     0.37421875,
#                     0.5027777777777778,
#                     0.05703125,
#                     0.09861111111111111,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Flower',
#                 'iscrowd': 0,
#             }>,
#         ]),
#     }>,
#     'segmentations': <Detections: {
#         'detections': BaseList([
#             <Detection: {
#                 'id': '6154b03d02522f81348fa146',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Square',
#                 'bounding_box': BaseList([0.459375, 0.625, 0.053125, 0.15555555555555556]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Square',
#                 'iscrowd': 0,
#             }>,
#             <Detection: {
#                 'id': '6154b03d02522f81348fa147',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Flower',
#                 'bounding_box': BaseList([
#                     0.37421875,
#                     0.5027777777777778,
#                     0.05703125,
#                     0.09861111111111111,
#                 ]),
#                 'mask': array([[False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        ...,
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False],
#                        [False, False, False, ..., False, False, False]]),
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': 'Flower',
#                 'iscrowd': 0,
#             }>,
#         ]),
#     }>,
# }>]

# %%
session = fo.launch_app(dataset)
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?notebook=true&handleId=f68eef3e-bddf-4be4-8dd0-2006af481fdb"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
dataset = fo.Dataset(
    "/path/to/dataset_dir", 
    dataset_type=fo.types.COCODetectionDataset, 
    name="my_dataset"
)
