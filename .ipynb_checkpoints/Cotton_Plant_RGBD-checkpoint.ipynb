# %%
import open3d as o3d
import numpy as np
import cv2
import matplotlib.pyplot as plt
# Out:
# INFO - 2021-09-01 01:27:44,698 - font_manager - Generating new fontManager, this may take some time...
# INFO - 2021-09-01 01:27:45,884 - font_manager - Failed to extract font properties from /usr/share/fonts/truetype/noto/NotoColorEmoji.ttf: In FT2Font: Could not set the fontsize (error code 0x17)

# %%
rgb_image = cv2.imread('78.jpg')
depth_image = cv2.imread('78.png')

# %%
plt.imshow(depth_image, cmap = 'jet')
plt.clim(0,1)
